# %%
# Data format
# import datetime
from data_tmp import UsageEvent


from base_bloom import BloomFilter
from base_hll import HyperLogLog
# from base_reservoir import
# from base_map_reduce import
 

from typing import List, Dict, Set, Optional, Tuple
from datetime import datetime, timedelta
import mmh3
from collections import defaultdict
import itertools
import math
import random
from bitarray import bitarray

# %%
UsageEvent
# Out:
# data_tmp.UsageEvent

# %%
class StreamingAnalyser:
    def __init__(self,
                 hll_precision: int = 14,
                 bloom_size: int = 100000,
                 bloom_hash_count: int = 5,
                 time_window: timedelta = timedelta(hours=1)):
        
        # Ініціалізація компонентів
        # Унікальні глядачі
        self.track_listeners = defaultdict(lambda: HyperLogLog(hll_precision))
        # Повторні перегляди
        self.repeat_listens  = BloomFilter(bloom_size, bloom_hash_count)
        
        # Статистика прослуховувань
        self.listen_counts = defaultdict(int)
        self.completion_stats = defaultdict(lambda: defaultdict(int))
        self.device_stats = defaultdict(lambda: defaultdict(int))
        
        # Аналіз плейлистів та рекомендацій
        self.user_sequences = defaultdict(list)
        self.track_correlations = defaultdict(lambda: defaultdict(int))
        
        # Часові метрики
        self.time_window = time_window
        self.window_stats = []
        self.hourly_stats = defaultdict(lambda: defaultdict(int))
        
        # Додаткова статистика
        self.duration_points = defaultdict(list)

    def proccesor(self, event):
        """Обробляє подію прослуховування."""
        # Конвертуємо timestamp в datetime
        event_time = datetime.strptime(event.timestamp, '%Y-%m-%d %H:%M:%S')
        
        # Оновлюємо HyperLogLog
        self.track_listeners[event.music_id].add(event.user_id)
        
        # Перевіряємо повторне прослуховування
        listen_key = f"{event.user_id}:{event.music_id}:{event_time.date()}"
        is_repeat = self.repeat_listens.check(listen_key)
        self.repeat_listens.add(listen_key)
        
        # Оновлюємо всі метрики
        self._update_listen_stats(event)
        self._update_device_stats(event)
        self._update_user_sequences(event)
        self._update_time_window(event, event_time)
        self._update_duration_stats(event)


  
    def _update_listen_stats(self, event: UsageEvent) -> None:
        """Оновлює статистику прослуховувань."""
        self.listen_counts[event.music_id] += 1
        
        if event.completed.lower() == 'true':
            self.completion_stats[event.music_id]['completed'] += 1
        self.completion_stats[event.music_id]['total'] += 1
    
    def _update_device_stats(self, event: UsageEvent) -> None:
        """Оновлює статистику пристроїв."""
        self.device_stats[event.music_id][event.device] += 1
    
    def _update_user_sequences(self, event: UsageEvent) -> None:
        """Оновлює послідовності прослуховувань для рекомендацій."""
        user_seq = self.user_sequences[event.user_id]
        if user_seq:
            last_track = user_seq[-1]
            self.track_correlations[last_track][event.music_id] += 1
        
        user_seq.append(event.music_id)
        if len(user_seq) > 10:  # Зберігаємо останні 10 треків
            user_seq.pop(0)
    
    def _update_time_window(self, event: UsageEvent, event_time: datetime) -> None:
        """Підтримує ковзне вікно для аналізу трендів."""
        self.window_stats = [
            (ts, track) for ts, track in self.window_stats 
            if event_time - ts <= self.time_window
        ]
        
        self.window_stats.append((event_time, event.music_id))
        self.hourly_stats[event.music_id][event_time.hour] += 1
    
    def _update_duration_stats(self, event: UsageEvent) -> None:
        """Оновлює статистику тривалості прослуховування."""
        try:
            duration = float(event.duration_point)
            self.duration_points[event.music_id].append(duration)
        except (ValueError, TypeError):
            pass  # Пропускаємо некоректні значення
    
    def get_trending_tracks(self, top_n: int = 10) -> List[Tuple[str, int]]:
        """Повертає трендові треки на основі поточного вікна."""
        window_counts = defaultdict(int)
        for _, track_id in self.window_stats:
            window_counts[track_id] += 1
        
        return sorted(
            window_counts.items(),
            key=lambda x: x[1],
            reverse=True
        )[:top_n]
    
    def get_track_recommendations(self, track_id: str, limit: int = 5) -> List[Tuple[str, float]]:
        """Повертає рекомендації на основі кореляцій прослуховувань."""
        correlations = self.track_correlations[track_id]
        if not correlations:
            return []
        
        total_plays = sum(correlations.values())
        normalized = [
            (track, count / total_plays)
            for track, count in correlations.items()
        ]
        
        return sorted(normalized, key=lambda x: x[1], reverse=True)[:limit]
    
    def get_track_stats(self, track_id: str) -> Dict[str, any]:
        """Повертає детальну статистику для треку."""
        completion_stats = self.completion_stats[track_id]
        duration_points = self.duration_points[track_id]
        
        return {
            'total_plays': self.listen_counts[track_id],
            'unique_listeners': int(self.track_listeners[track_id].estimate()),
            'avg_duration': sum(duration_points) / len(duration_points) if duration_points else 0,
            'completion_rate': (
                completion_stats['completed'] / completion_stats['total']
                if completion_stats['total'] > 0 else 0
            ),
            'device_distribution': {
                device: count / self.listen_counts[track_id]
                for device, count in self.device_stats[track_id].items()
            },
            'hourly_distribution': dict(self.hourly_stats[track_id])
        }

# %%
import random
import string
import time
from dataclasses import dataclass
from typing import Generator

def random_string(length: int) -> str:
    """Generate a random string of uppercase letters and digits."""
    return ''.join(random.choices(string.ascii_uppercase + string.digits, k=length))

def generate_usage_events():
    """A generator that yields random UsageEvent objects."""
    devices = ["mobile", "desktop", "tablet", "smart_tv"]
    track_ids = [f"track_{i}" for i in range(100)]
    user_ids = [f"user_{i}" for i in range(1000)]

    while True:
        user_id = random.choice(user_ids)
        music_id = random.choice(track_ids)
        timestamp = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
        duration_point = str(random.randint(30, 300))  # Duration in seconds (30 to 300 seconds)
        completed = random.choice(["true", "false"])
        device = random.choice(devices)

        yield UsageEvent(
            user_id=user_id,
            music_id=music_id,
            timestamp=timestamp,
            duration_point=duration_point,
            completed=completed,
            device=device
        )

# %%
analizer = StreamingAnalyser()
event_generator = generate_usage_events()


for _ in range(10000):  # Generate 5 events for demonstration
    event = next(event_generator)
    print(event)
    analizer.proccesor(event)
# Out:
# UsageEvent(user_id='user_457', music_id='track_34', timestamp='2025-01-19 17:22:44', duration_point='250', completed='false', device='smart_tv')
# UsageEvent(user_id='user_436', music_id='track_37', timestamp='2025-01-19 17:22:44', duration_point='290', completed='false', device='smart_tv')
# UsageEvent(user_id='user_979', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='219', completed='false', device='smart_tv')
# UsageEvent(user_id='user_109', music_id='track_82', timestamp='2025-01-19 17:22:44', duration_point='240', completed='false', device='tablet')
# UsageEvent(user_id='user_497', music_id='track_84', timestamp='2025-01-19 17:22:44', duration_point='52', completed='true', device='smart_tv')
# UsageEvent(user_id='user_634', music_id='track_30', timestamp='2025-01-19 17:22:44', duration_point='68', completed='false', device='smart_tv')
# UsageEvent(user_id='user_434', music_id='track_74', timestamp='2025-01-19 17:22:44', duration_point='207', completed='false', device='desktop')
# UsageEvent(user_id='user_356', music_id='track_86', timestamp='2025-01-19 17:22:44', duration_point='205', completed='false', device='smart_tv')
# UsageEvent(user_id='user_148', music_id='track_76', timestamp='2025-01-19 17:22:44', duration_point='49', completed='false', device='desktop')
# UsageEvent(user_id='user_602', music_id='track_75', timestamp='2025-01-19 17:22:44', duration_point='279', completed='true', device='tablet')
# UsageEvent(user_id='user_140', music_id='track_59', timestamp='2025-01-19 17:22:44', duration_point='142', completed='false', device='mobile')
# UsageEvent(user_id='user_515', music_id='track_32', timestamp='2025-01-19 17:22:44', duration_point='205', completed='false', device='desktop')
# UsageEvent(user_id='user_695', music_id='track_69', timestamp='2025-01-19 17:22:44', duration_point='291', completed='true', device='mobile')
# UsageEvent(user_id='user_618', music_id='track_16', timestamp='2025-01-19 17:22:44', duration_point='283', completed='false', device='desktop')
# UsageEvent(user_id='user_887', music_id='track_58', timestamp='2025-01-19 17:22:44', duration_point='31', completed='true', device='desktop')
# UsageEvent(user_id='user_271', music_id='track_30', timestamp='2025-01-19 17:22:44', duration_point='135', completed='false', device='tablet')
# UsageEvent(user_id='user_413', music_id='track_43', timestamp='2025-01-19 17:22:44', duration_point='222', completed='true', device='smart_tv')
# UsageEvent(user_id='user_888', music_id='track_85', timestamp='2025-01-19 17:22:44', duration_point='110', completed='false', device='mobile')
# UsageEvent(user_id='user_755', music_id='track_19', timestamp='2025-01-19 17:22:44', duration_point='116', completed='true', device='smart_tv')
# UsageEvent(user_id='user_584', music_id='track_92', timestamp='2025-01-19 17:22:44', duration_point='194', completed='true', device='smart_tv')
# UsageEvent(user_id='user_72', music_id='track_85', timestamp='2025-01-19 17:22:44', duration_point='218', completed='false', device='desktop')
# UsageEvent(user_id='user_805', music_id='track_27', timestamp='2025-01-19 17:22:44', duration_point='50', completed='true', device='smart_tv')
# UsageEvent(user_id='user_508', music_id='track_85', timestamp='2025-01-19 17:22:44', duration_point='127', completed='false', device='desktop')
# UsageEvent(user_id='user_799', music_id='track_75', timestamp='2025-01-19 17:22:44', duration_point='79', completed='false', device='smart_tv')
# UsageEvent(user_id='user_687', music_id='track_34', timestamp='2025-01-19 17:22:44', duration_point='247', completed='false', device='tablet')
# UsageEvent(user_id='user_413', music_id='track_17', timestamp='2025-01-19 17:22:44', duration_point='131', completed='false', device='desktop')
# UsageEvent(user_id='user_653', music_id='track_19', timestamp='2025-01-19 17:22:44', duration_point='214', completed='true', device='smart_tv')
# UsageEvent(user_id='user_33', music_id='track_36', timestamp='2025-01-19 17:22:44', duration_point='265', completed='true', device='smart_tv')
# UsageEvent(user_id='user_641', music_id='track_89', timestamp='2025-01-19 17:22:44', duration_point='148', completed='false', device='tablet')
# UsageEvent(user_id='user_758', music_id='track_13', timestamp='2025-01-19 17:22:44', duration_point='61', completed='true', device='desktop')
# UsageEvent(user_id='user_425', music_id='track_37', timestamp='2025-01-19 17:22:44', duration_point='261', completed='true', device='smart_tv')
# UsageEvent(user_id='user_433', music_id='track_3', timestamp='2025-01-19 17:22:44', duration_point='241', completed='false', device='mobile')
# UsageEvent(user_id='user_807', music_id='track_94', timestamp='2025-01-19 17:22:44', duration_point='194', completed='false', device='tablet')
# UsageEvent(user_id='user_796', music_id='track_10', timestamp='2025-01-19 17:22:44', duration_point='41', completed='false', device='tablet')
# UsageEvent(user_id='user_435', music_id='track_72', timestamp='2025-01-19 17:22:44', duration_point='160', completed='false', device='desktop')
# UsageEvent(user_id='user_973', music_id='track_96', timestamp='2025-01-19 17:22:44', duration_point='247', completed='false', device='mobile')
# UsageEvent(user_id='user_4', music_id='track_20', timestamp='2025-01-19 17:22:44', duration_point='80', completed='true', device='mobile')
# UsageEvent(user_id='user_673', music_id='track_70', timestamp='2025-01-19 17:22:44', duration_point='187', completed='false', device='tablet')
# UsageEvent(user_id='user_352', music_id='track_36', timestamp='2025-01-19 17:22:44', duration_point='109', completed='false', device='desktop')
# UsageEvent(user_id='user_69', music_id='track_90', timestamp='2025-01-19 17:22:44', duration_point='153', completed='true', device='desktop')
# UsageEvent(user_id='user_6', music_id='track_25', timestamp='2025-01-19 17:22:44', duration_point='295', completed='true', device='tablet')
# UsageEvent(user_id='user_793', music_id='track_20', timestamp='2025-01-19 17:22:44', duration_point='85', completed='false', device='tablet')
# UsageEvent(user_id='user_506', music_id='track_84', timestamp='2025-01-19 17:22:44', duration_point='73', completed='true', device='tablet')
# UsageEvent(user_id='user_501', music_id='track_21', timestamp='2025-01-19 17:22:44', duration_point='59', completed='true', device='smart_tv')
# UsageEvent(user_id='user_404', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='39', completed='false', device='desktop')
# UsageEvent(user_id='user_726', music_id='track_23', timestamp='2025-01-19 17:22:44', duration_point='233', completed='false', device='desktop')
# UsageEvent(user_id='user_879', music_id='track_87', timestamp='2025-01-19 17:22:44', duration_point='111', completed='false', device='smart_tv')
# UsageEvent(user_id='user_525', music_id='track_88', timestamp='2025-01-19 17:22:44', duration_point='40', completed='false', device='desktop')
# UsageEvent(user_id='user_144', music_id='track_82', timestamp='2025-01-19 17:22:44', duration_point='280', completed='false', device='tablet')
# UsageEvent(user_id='user_222', music_id='track_48', timestamp='2025-01-19 17:22:44', duration_point='193', completed='true', device='desktop')
# UsageEvent(user_id='user_912', music_id='track_7', timestamp='2025-01-19 17:22:44', duration_point='291', completed='true', device='smart_tv')
# UsageEvent(user_id='user_635', music_id='track_6', timestamp='2025-01-19 17:22:44', duration_point='275', completed='false', device='smart_tv')
# UsageEvent(user_id='user_648', music_id='track_35', timestamp='2025-01-19 17:22:44', duration_point='288', completed='false', device='smart_tv')
# UsageEvent(user_id='user_289', music_id='track_19', timestamp='2025-01-19 17:22:44', duration_point='293', completed='true', device='mobile')
# UsageEvent(user_id='user_83', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='41', completed='true', device='desktop')
# UsageEvent(user_id='user_786', music_id='track_17', timestamp='2025-01-19 17:22:44', duration_point='106', completed='true', device='smart_tv')
# UsageEvent(user_id='user_685', music_id='track_84', timestamp='2025-01-19 17:22:44', duration_point='113', completed='false', device='tablet')
# UsageEvent(user_id='user_955', music_id='track_53', timestamp='2025-01-19 17:22:44', duration_point='162', completed='true', device='smart_tv')
# UsageEvent(user_id='user_369', music_id='track_31', timestamp='2025-01-19 17:22:44', duration_point='71', completed='false', device='desktop')
# UsageEvent(user_id='user_442', music_id='track_48', timestamp='2025-01-19 17:22:44', duration_point='129', completed='true', device='mobile')
# UsageEvent(user_id='user_383', music_id='track_92', timestamp='2025-01-19 17:22:44', duration_point='180', completed='false', device='smart_tv')
# UsageEvent(user_id='user_783', music_id='track_0', timestamp='2025-01-19 17:22:44', duration_point='33', completed='false', device='desktop')
# UsageEvent(user_id='user_777', music_id='track_88', timestamp='2025-01-19 17:22:44', duration_point='193', completed='true', device='mobile')
# UsageEvent(user_id='user_818', music_id='track_63', timestamp='2025-01-19 17:22:44', duration_point='58', completed='false', device='smart_tv')
# UsageEvent(user_id='user_224', music_id='track_92', timestamp='2025-01-19 17:22:44', duration_point='182', completed='false', device='smart_tv')
# UsageEvent(user_id='user_247', music_id='track_3', timestamp='2025-01-19 17:22:44', duration_point='114', completed='true', device='smart_tv')
# UsageEvent(user_id='user_129', music_id='track_20', timestamp='2025-01-19 17:22:44', duration_point='180', completed='true', device='tablet')
# UsageEvent(user_id='user_887', music_id='track_98', timestamp='2025-01-19 17:22:44', duration_point='296', completed='false', device='desktop')
# UsageEvent(user_id='user_463', music_id='track_74', timestamp='2025-01-19 17:22:44', duration_point='263', completed='false', device='desktop')
# UsageEvent(user_id='user_668', music_id='track_87', timestamp='2025-01-19 17:22:44', duration_point='56', completed='false', device='desktop')
# UsageEvent(user_id='user_397', music_id='track_51', timestamp='2025-01-19 17:22:44', duration_point='95', completed='false', device='desktop')
# UsageEvent(user_id='user_900', music_id='track_46', timestamp='2025-01-19 17:22:44', duration_point='106', completed='false', device='mobile')
# UsageEvent(user_id='user_54', music_id='track_92', timestamp='2025-01-19 17:22:44', duration_point='294', completed='false', device='mobile')
# UsageEvent(user_id='user_184', music_id='track_61', timestamp='2025-01-19 17:22:44', duration_point='161', completed='false', device='tablet')
# UsageEvent(user_id='user_954', music_id='track_42', timestamp='2025-01-19 17:22:44', duration_point='58', completed='false', device='mobile')
# UsageEvent(user_id='user_320', music_id='track_42', timestamp='2025-01-19 17:22:44', duration_point='235', completed='true', device='tablet')
# UsageEvent(user_id='user_812', music_id='track_86', timestamp='2025-01-19 17:22:44', duration_point='273', completed='true', device='smart_tv')
# UsageEvent(user_id='user_250', music_id='track_55', timestamp='2025-01-19 17:22:44', duration_point='215', completed='true', device='tablet')
# UsageEvent(user_id='user_479', music_id='track_45', timestamp='2025-01-19 17:22:44', duration_point='147', completed='true', device='desktop')
# UsageEvent(user_id='user_524', music_id='track_61', timestamp='2025-01-19 17:22:44', duration_point='186', completed='false', device='mobile')
# UsageEvent(user_id='user_900', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='288', completed='true', device='mobile')
# UsageEvent(user_id='user_438', music_id='track_16', timestamp='2025-01-19 17:22:44', duration_point='148', completed='true', device='smart_tv')
# UsageEvent(user_id='user_102', music_id='track_28', timestamp='2025-01-19 17:22:44', duration_point='90', completed='true', device='mobile')
# UsageEvent(user_id='user_137', music_id='track_97', timestamp='2025-01-19 17:22:44', duration_point='186', completed='true', device='desktop')
# UsageEvent(user_id='user_711', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='30', completed='false', device='mobile')
# UsageEvent(user_id='user_996', music_id='track_56', timestamp='2025-01-19 17:22:44', duration_point='148', completed='false', device='desktop')
# UsageEvent(user_id='user_14', music_id='track_73', timestamp='2025-01-19 17:22:44', duration_point='214', completed='false', device='tablet')
# UsageEvent(user_id='user_491', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='91', completed='true', device='tablet')
# UsageEvent(user_id='user_78', music_id='track_74', timestamp='2025-01-19 17:22:44', duration_point='192', completed='true', device='smart_tv')
# UsageEvent(user_id='user_963', music_id='track_16', timestamp='2025-01-19 17:22:44', duration_point='169', completed='false', device='mobile')
# UsageEvent(user_id='user_799', music_id='track_69', timestamp='2025-01-19 17:22:44', duration_point='37', completed='true', device='desktop')
# UsageEvent(user_id='user_843', music_id='track_2', timestamp='2025-01-19 17:22:44', duration_point='66', completed='true', device='smart_tv')
# UsageEvent(user_id='user_396', music_id='track_36', timestamp='2025-01-19 17:22:44', duration_point='40', completed='false', device='tablet')
# UsageEvent(user_id='user_207', music_id='track_63', timestamp='2025-01-19 17:22:44', duration_point='163', completed='false', device='smart_tv')
# UsageEvent(user_id='user_509', music_id='track_75', timestamp='2025-01-19 17:22:44', duration_point='135', completed='false', device='smart_tv')
# UsageEvent(user_id='user_278', music_id='track_63', timestamp='2025-01-19 17:22:44', duration_point='181', completed='false', device='smart_tv')
# UsageEvent(user_id='user_353', music_id='track_5', timestamp='2025-01-19 17:22:44', duration_point='31', completed='true', device='tablet')
# UsageEvent(user_id='user_157', music_id='track_88', timestamp='2025-01-19 17:22:44', duration_point='175', completed='true', device='tablet')
# UsageEvent(user_id='user_810', music_id='track_78', timestamp='2025-01-19 17:22:44', duration_point='48', completed='false', device='mobile')
# UsageEvent(user_id='user_109', music_id='track_28', timestamp='2025-01-19 17:22:44', duration_point='239', completed='false', device='mobile')
# UsageEvent(user_id='user_317', music_id='track_98', timestamp='2025-01-19 17:22:44', duration_point='95', completed='false', device='smart_tv')
# UsageEvent(user_id='user_570', music_id='track_12', timestamp='2025-01-19 17:22:44', duration_point='244', completed='false', device='mobile')
# UsageEvent(user_id='user_557', music_id='track_48', timestamp='2025-01-19 17:22:44', duration_point='82', completed='false', device='smart_tv')
# UsageEvent(user_id='user_300', music_id='track_71', timestamp='2025-01-19 17:22:44', duration_point='138', completed='true', device='smart_tv')
# UsageEvent(user_id='user_581', music_id='track_72', timestamp='2025-01-19 17:22:44', duration_point='289', completed='false', device='tablet')
# UsageEvent(user_id='user_740', music_id='track_11', timestamp='2025-01-19 17:22:44', duration_point='139', completed='true', device='tablet')
# UsageEvent(user_id='user_984', music_id='track_31', timestamp='2025-01-19 17:22:44', duration_point='111', completed='true', device='smart_tv')
# UsageEvent(user_id='user_54', music_id='track_67', timestamp='2025-01-19 17:22:44', duration_point='173', completed='true', device='desktop')
# UsageEvent(user_id='user_52', music_id='track_62', timestamp='2025-01-19 17:22:44', duration_point='245', completed='true', device='smart_tv')
# UsageEvent(user_id='user_438', music_id='track_63', timestamp='2025-01-19 17:22:44', duration_point='195', completed='true', device='smart_tv')
# UsageEvent(user_id='user_309', music_id='track_13', timestamp='2025-01-19 17:22:44', duration_point='39', completed='false', device='desktop')
# UsageEvent(user_id='user_307', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='163', completed='true', device='tablet')
# UsageEvent(user_id='user_545', music_id='track_14', timestamp='2025-01-19 17:22:44', duration_point='85', completed='false', device='smart_tv')
# UsageEvent(user_id='user_341', music_id='track_10', timestamp='2025-01-19 17:22:44', duration_point='112', completed='false', device='tablet')
# UsageEvent(user_id='user_12', music_id='track_70', timestamp='2025-01-19 17:22:44', duration_point='183', completed='true', device='desktop')
# UsageEvent(user_id='user_104', music_id='track_29', timestamp='2025-01-19 17:22:44', duration_point='191', completed='false', device='mobile')
# UsageEvent(user_id='user_527', music_id='track_23', timestamp='2025-01-19 17:22:44', duration_point='258', completed='false', device='mobile')
# UsageEvent(user_id='user_977', music_id='track_88', timestamp='2025-01-19 17:22:44', duration_point='212', completed='true', device='mobile')
# UsageEvent(user_id='user_651', music_id='track_92', timestamp='2025-01-19 17:22:44', duration_point='118', completed='true', device='tablet')
# UsageEvent(user_id='user_555', music_id='track_47', timestamp='2025-01-19 17:22:44', duration_point='208', completed='false', device='desktop')
# UsageEvent(user_id='user_387', music_id='track_3', timestamp='2025-01-19 17:22:44', duration_point='82', completed='false', device='desktop')
# UsageEvent(user_id='user_157', music_id='track_6', timestamp='2025-01-19 17:22:44', duration_point='98', completed='false', device='mobile')
# UsageEvent(user_id='user_289', music_id='track_73', timestamp='2025-01-19 17:22:44', duration_point='76', completed='true', device='smart_tv')
# UsageEvent(user_id='user_183', music_id='track_25', timestamp='2025-01-19 17:22:44', duration_point='107', completed='false', device='mobile')
# UsageEvent(user_id='user_121', music_id='track_92', timestamp='2025-01-19 17:22:44', duration_point='215', completed='false', device='mobile')
# UsageEvent(user_id='user_974', music_id='track_19', timestamp='2025-01-19 17:22:44', duration_point='105', completed='false', device='mobile')
# UsageEvent(user_id='user_817', music_id='track_82', timestamp='2025-01-19 17:22:44', duration_point='276', completed='true', device='tablet')
# UsageEvent(user_id='user_841', music_id='track_34', timestamp='2025-01-19 17:22:44', duration_point='134', completed='false', device='tablet')
# UsageEvent(user_id='user_732', music_id='track_93', timestamp='2025-01-19 17:22:44', duration_point='266', completed='false', device='mobile')
# UsageEvent(user_id='user_547', music_id='track_58', timestamp='2025-01-19 17:22:44', duration_point='128', completed='false', device='smart_tv')
# UsageEvent(user_id='user_639', music_id='track_37', timestamp='2025-01-19 17:22:44', duration_point='148', completed='true', device='mobile')
# UsageEvent(user_id='user_48', music_id='track_92', timestamp='2025-01-19 17:22:44', duration_point='82', completed='true', device='smart_tv')
# UsageEvent(user_id='user_463', music_id='track_80', timestamp='2025-01-19 17:22:44', duration_point='246', completed='true', device='smart_tv')
# UsageEvent(user_id='user_783', music_id='track_73', timestamp='2025-01-19 17:22:44', duration_point='198', completed='true', device='mobile')
# UsageEvent(user_id='user_127', music_id='track_85', timestamp='2025-01-19 17:22:44', duration_point='126', completed='false', device='mobile')
# UsageEvent(user_id='user_598', music_id='track_58', timestamp='2025-01-19 17:22:44', duration_point='73', completed='true', device='tablet')
# UsageEvent(user_id='user_246', music_id='track_27', timestamp='2025-01-19 17:22:44', duration_point='252', completed='false', device='tablet')
# UsageEvent(user_id='user_803', music_id='track_22', timestamp='2025-01-19 17:22:44', duration_point='93', completed='false', device='mobile')
# UsageEvent(user_id='user_609', music_id='track_57', timestamp='2025-01-19 17:22:44', duration_point='92', completed='false', device='mobile')
# UsageEvent(user_id='user_530', music_id='track_34', timestamp='2025-01-19 17:22:44', duration_point='269', completed='true', device='smart_tv')
# UsageEvent(user_id='user_37', music_id='track_47', timestamp='2025-01-19 17:22:44', duration_point='43', completed='true', device='tablet')
# UsageEvent(user_id='user_4', music_id='track_82', timestamp='2025-01-19 17:22:44', duration_point='254', completed='true', device='mobile')
# UsageEvent(user_id='user_488', music_id='track_38', timestamp='2025-01-19 17:22:44', duration_point='293', completed='true', device='smart_tv')
# UsageEvent(user_id='user_388', music_id='track_74', timestamp='2025-01-19 17:22:44', duration_point='138', completed='true', device='tablet')
# UsageEvent(user_id='user_171', music_id='track_36', timestamp='2025-01-19 17:22:44', duration_point='157', completed='false', device='smart_tv')
# UsageEvent(user_id='user_630', music_id='track_27', timestamp='2025-01-19 17:22:44', duration_point='293', completed='true', device='tablet')
# UsageEvent(user_id='user_268', music_id='track_67', timestamp='2025-01-19 17:22:44', duration_point='289', completed='false', device='smart_tv')
# UsageEvent(user_id='user_124', music_id='track_3', timestamp='2025-01-19 17:22:44', duration_point='47', completed='true', device='tablet')
# UsageEvent(user_id='user_220', music_id='track_32', timestamp='2025-01-19 17:22:44', duration_point='293', completed='false', device='tablet')
# UsageEvent(user_id='user_614', music_id='track_49', timestamp='2025-01-19 17:22:44', duration_point='299', completed='false', device='tablet')
# UsageEvent(user_id='user_225', music_id='track_62', timestamp='2025-01-19 17:22:44', duration_point='273', completed='true', device='smart_tv')
# UsageEvent(user_id='user_560', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='37', completed='false', device='desktop')
# UsageEvent(user_id='user_748', music_id='track_2', timestamp='2025-01-19 17:22:44', duration_point='33', completed='false', device='smart_tv')
# UsageEvent(user_id='user_256', music_id='track_3', timestamp='2025-01-19 17:22:44', duration_point='258', completed='true', device='mobile')
# UsageEvent(user_id='user_769', music_id='track_6', timestamp='2025-01-19 17:22:44', duration_point='45', completed='false', device='desktop')
# UsageEvent(user_id='user_568', music_id='track_6', timestamp='2025-01-19 17:22:44', duration_point='70', completed='false', device='desktop')
# UsageEvent(user_id='user_448', music_id='track_41', timestamp='2025-01-19 17:22:44', duration_point='50', completed='false', device='tablet')
# UsageEvent(user_id='user_459', music_id='track_51', timestamp='2025-01-19 17:22:44', duration_point='269', completed='true', device='tablet')
# UsageEvent(user_id='user_43', music_id='track_99', timestamp='2025-01-19 17:22:44', duration_point='75', completed='true', device='smart_tv')
# UsageEvent(user_id='user_886', music_id='track_5', timestamp='2025-01-19 17:22:44', duration_point='298', completed='false', device='desktop')
# UsageEvent(user_id='user_985', music_id='track_26', timestamp='2025-01-19 17:22:44', duration_point='187', completed='false', device='mobile')
# UsageEvent(user_id='user_35', music_id='track_83', timestamp='2025-01-19 17:22:44', duration_point='250', completed='false', device='smart_tv')
# UsageEvent(user_id='user_242', music_id='track_28', timestamp='2025-01-19 17:22:44', duration_point='148', completed='false', device='smart_tv')
# UsageEvent(user_id='user_64', music_id='track_68', timestamp='2025-01-19 17:22:44', duration_point='165', completed='false', device='desktop')
# UsageEvent(user_id='user_74', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='49', completed='false', device='smart_tv')
# UsageEvent(user_id='user_273', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='48', completed='true', device='mobile')
# UsageEvent(user_id='user_261', music_id='track_13', timestamp='2025-01-19 17:22:44', duration_point='60', completed='true', device='desktop')
# UsageEvent(user_id='user_53', music_id='track_56', timestamp='2025-01-19 17:22:44', duration_point='189', completed='false', device='desktop')
# UsageEvent(user_id='user_174', music_id='track_94', timestamp='2025-01-19 17:22:44', duration_point='171', completed='true', device='smart_tv')
# UsageEvent(user_id='user_356', music_id='track_21', timestamp='2025-01-19 17:22:44', duration_point='92', completed='false', device='mobile')
# UsageEvent(user_id='user_794', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='146', completed='true', device='smart_tv')
# UsageEvent(user_id='user_955', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='233', completed='true', device='smart_tv')
# UsageEvent(user_id='user_910', music_id='track_82', timestamp='2025-01-19 17:22:44', duration_point='203', completed='false', device='tablet')
# UsageEvent(user_id='user_26', music_id='track_84', timestamp='2025-01-19 17:22:44', duration_point='247', completed='true', device='smart_tv')
# UsageEvent(user_id='user_903', music_id='track_66', timestamp='2025-01-19 17:22:44', duration_point='127', completed='true', device='smart_tv')
# UsageEvent(user_id='user_215', music_id='track_89', timestamp='2025-01-19 17:22:44', duration_point='170', completed='true', device='desktop')
# UsageEvent(user_id='user_447', music_id='track_10', timestamp='2025-01-19 17:22:44', duration_point='31', completed='false', device='desktop')
# UsageEvent(user_id='user_831', music_id='track_33', timestamp='2025-01-19 17:22:44', duration_point='70', completed='false', device='mobile')
# UsageEvent(user_id='user_782', music_id='track_31', timestamp='2025-01-19 17:22:44', duration_point='272', completed='true', device='tablet')
# UsageEvent(user_id='user_699', music_id='track_1', timestamp='2025-01-19 17:22:44', duration_point='258', completed='true', device='smart_tv')
# UsageEvent(user_id='user_428', music_id='track_80', timestamp='2025-01-19 17:22:44', duration_point='247', completed='false', device='smart_tv')
# UsageEvent(user_id='user_346', music_id='track_50', timestamp='2025-01-19 17:22:44', duration_point='146', completed='false', device='desktop')
# UsageEvent(user_id='user_71', music_id='track_72', timestamp='2025-01-19 17:22:44', duration_point='229', completed='false', device='mobile')
# UsageEvent(user_id='user_272', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='119', completed='true', device='mobile')
# UsageEvent(user_id='user_988', music_id='track_50', timestamp='2025-01-19 17:22:44', duration_point='131', completed='false', device='mobile')
# UsageEvent(user_id='user_647', music_id='track_39', timestamp='2025-01-19 17:22:44', duration_point='138', completed='true', device='desktop')
# UsageEvent(user_id='user_968', music_id='track_31', timestamp='2025-01-19 17:22:44', duration_point='161', completed='false', device='mobile')
# UsageEvent(user_id='user_281', music_id='track_41', timestamp='2025-01-19 17:22:44', duration_point='88', completed='false', device='desktop')
# UsageEvent(user_id='user_749', music_id='track_35', timestamp='2025-01-19 17:22:44', duration_point='163', completed='true', device='mobile')
# UsageEvent(user_id='user_14', music_id='track_98', timestamp='2025-01-19 17:22:44', duration_point='194', completed='true', device='mobile')
# UsageEvent(user_id='user_215', music_id='track_60', timestamp='2025-01-19 17:22:44', duration_point='249', completed='false', device='mobile')
# UsageEvent(user_id='user_216', music_id='track_21', timestamp='2025-01-19 17:22:44', duration_point='241', completed='true', device='smart_tv')
# UsageEvent(user_id='user_307', music_id='track_69', timestamp='2025-01-19 17:22:44', duration_point='239', completed='false', device='desktop')
# UsageEvent(user_id='user_42', music_id='track_93', timestamp='2025-01-19 17:22:44', duration_point='49', completed='false', device='mobile')
# UsageEvent(user_id='user_269', music_id='track_89', timestamp='2025-01-19 17:22:44', duration_point='106', completed='true', device='desktop')
# UsageEvent(user_id='user_704', music_id='track_34', timestamp='2025-01-19 17:22:44', duration_point='193', completed='true', device='desktop')
# UsageEvent(user_id='user_693', music_id='track_82', timestamp='2025-01-19 17:22:44', duration_point='36', completed='true', device='mobile')
# UsageEvent(user_id='user_894', music_id='track_48', timestamp='2025-01-19 17:22:44', duration_point='86', completed='false', device='mobile')
# UsageEvent(user_id='user_646', music_id='track_33', timestamp='2025-01-19 17:22:44', duration_point='253', completed='true', device='tablet')
# UsageEvent(user_id='user_181', music_id='track_47', timestamp='2025-01-19 17:22:44', duration_point='189', completed='true', device='tablet')
# UsageEvent(user_id='user_944', music_id='track_50', timestamp='2025-01-19 17:22:44', duration_point='224', completed='true', device='mobile')
# UsageEvent(user_id='user_748', music_id='track_86', timestamp='2025-01-19 17:22:44', duration_point='244', completed='true', device='mobile')
# UsageEvent(user_id='user_982', music_id='track_74', timestamp='2025-01-19 17:22:44', duration_point='231', completed='true', device='smart_tv')
# UsageEvent(user_id='user_114', music_id='track_20', timestamp='2025-01-19 17:22:44', duration_point='268', completed='true', device='desktop')
# UsageEvent(user_id='user_434', music_id='track_36', timestamp='2025-01-19 17:22:44', duration_point='263', completed='false', device='smart_tv')
# UsageEvent(user_id='user_699', music_id='track_65', timestamp='2025-01-19 17:22:44', duration_point='95', completed='true', device='tablet')
# UsageEvent(user_id='user_161', music_id='track_77', timestamp='2025-01-19 17:22:44', duration_point='46', completed='false', device='mobile')
# UsageEvent(user_id='user_910', music_id='track_5', timestamp='2025-01-19 17:22:44', duration_point='136', completed='true', device='tablet')
# UsageEvent(user_id='user_847', music_id='track_71', timestamp='2025-01-19 17:22:44', duration_point='97', completed='false', device='mobile')
# UsageEvent(user_id='user_422', music_id='track_38', timestamp='2025-01-19 17:22:44', duration_point='273', completed='false', device='desktop')
# UsageEvent(user_id='user_261', music_id='track_16', timestamp='2025-01-19 17:22:44', duration_point='206', completed='false', device='mobile')
# UsageEvent(user_id='user_997', music_id='track_98', timestamp='2025-01-19 17:22:44', duration_point='177', completed='true', device='mobile')
# UsageEvent(user_id='user_732', music_id='track_11', timestamp='2025-01-19 17:22:44', duration_point='288', completed='false', device='desktop')
# UsageEvent(user_id='user_785', music_id='track_96', timestamp='2025-01-19 17:22:44', duration_point='290', completed='true', device='desktop')
# UsageEvent(user_id='user_968', music_id='track_17', timestamp='2025-01-19 17:22:44', duration_point='260', completed='false', device='smart_tv')
# UsageEvent(user_id='user_782', music_id='track_81', timestamp='2025-01-19 17:22:44', duration_point='273', completed='false', device='desktop')
# UsageEvent(user_id='user_83', music_id='track_83', timestamp='2025-01-19 17:22:44', duration_point='291', completed='true', device='smart_tv')
# UsageEvent(user_id='user_848', music_id='track_50', timestamp='2025-01-19 17:22:44', duration_point='43', completed='true', device='mobile')
# UsageEvent(user_id='user_302', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='75', completed='true', device='mobile')
# UsageEvent(user_id='user_931', music_id='track_84', timestamp='2025-01-19 17:22:44', duration_point='213', completed='false', device='desktop')
# UsageEvent(user_id='user_524', music_id='track_39', timestamp='2025-01-19 17:22:44', duration_point='208', completed='true', device='tablet')
# UsageEvent(user_id='user_604', music_id='track_29', timestamp='2025-01-19 17:22:44', duration_point='283', completed='true', device='mobile')
# UsageEvent(user_id='user_474', music_id='track_68', timestamp='2025-01-19 17:22:44', duration_point='195', completed='false', device='tablet')
# UsageEvent(user_id='user_135', music_id='track_76', timestamp='2025-01-19 17:22:44', duration_point='189', completed='true', device='tablet')
# UsageEvent(user_id='user_695', music_id='track_22', timestamp='2025-01-19 17:22:44', duration_point='233', completed='true', device='smart_tv')
# UsageEvent(user_id='user_367', music_id='track_29', timestamp='2025-01-19 17:22:44', duration_point='116', completed='false', device='mobile')
# UsageEvent(user_id='user_443', music_id='track_67', timestamp='2025-01-19 17:22:44', duration_point='262', completed='true', device='mobile')
# UsageEvent(user_id='user_515', music_id='track_67', timestamp='2025-01-19 17:22:44', duration_point='88', completed='true', device='smart_tv')
# UsageEvent(user_id='user_366', music_id='track_20', timestamp='2025-01-19 17:22:44', duration_point='99', completed='true', device='desktop')
# UsageEvent(user_id='user_877', music_id='track_97', timestamp='2025-01-19 17:22:44', duration_point='278', completed='false', device='desktop')
# UsageEvent(user_id='user_774', music_id='track_88', timestamp='2025-01-19 17:22:44', duration_point='133', completed='false', device='smart_tv')
# UsageEvent(user_id='user_607', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='237', completed='true', device='desktop')
# UsageEvent(user_id='user_923', music_id='track_14', timestamp='2025-01-19 17:22:44', duration_point='70', completed='false', device='mobile')
# UsageEvent(user_id='user_383', music_id='track_93', timestamp='2025-01-19 17:22:44', duration_point='61', completed='true', device='smart_tv')
# UsageEvent(user_id='user_598', music_id='track_83', timestamp='2025-01-19 17:22:44', duration_point='200', completed='false', device='mobile')
# UsageEvent(user_id='user_817', music_id='track_18', timestamp='2025-01-19 17:22:44', duration_point='79', completed='false', device='smart_tv')
# UsageEvent(user_id='user_104', music_id='track_63', timestamp='2025-01-19 17:22:44', duration_point='41', completed='true', device='smart_tv')
# UsageEvent(user_id='user_731', music_id='track_66', timestamp='2025-01-19 17:22:44', duration_point='32', completed='true', device='tablet')
# UsageEvent(user_id='user_254', music_id='track_86', timestamp='2025-01-19 17:22:44', duration_point='194', completed='false', device='tablet')
# UsageEvent(user_id='user_813', music_id='track_58', timestamp='2025-01-19 17:22:44', duration_point='171', completed='false', device='mobile')
# UsageEvent(user_id='user_752', music_id='track_41', timestamp='2025-01-19 17:22:44', duration_point='102', completed='false', device='desktop')
# UsageEvent(user_id='user_311', music_id='track_48', timestamp='2025-01-19 17:22:44', duration_point='259', completed='true', device='desktop')
# UsageEvent(user_id='user_441', music_id='track_79', timestamp='2025-01-19 17:22:44', duration_point='196', completed='true', device='smart_tv')
# UsageEvent(user_id='user_131', music_id='track_74', timestamp='2025-01-19 17:22:44', duration_point='228', completed='true', device='mobile')
# UsageEvent(user_id='user_23', music_id='track_95', timestamp='2025-01-19 17:22:44', duration_point='67', completed='false', device='tablet')
# UsageEvent(user_id='user_102', music_id='track_77', timestamp='2025-01-19 17:22:44', duration_point='231', completed='false', device='tablet')
# UsageEvent(user_id='user_674', music_id='track_57', timestamp='2025-01-19 17:22:44', duration_point='52', completed='true', device='tablet')
# UsageEvent(user_id='user_757', music_id='track_56', timestamp='2025-01-19 17:22:44', duration_point='75', completed='false', device='mobile')
# UsageEvent(user_id='user_238', music_id='track_43', timestamp='2025-01-19 17:22:44', duration_point='267', completed='false', device='desktop')
# UsageEvent(user_id='user_769', music_id='track_28', timestamp='2025-01-19 17:22:44', duration_point='214', completed='true', device='tablet')
# UsageEvent(user_id='user_726', music_id='track_35', timestamp='2025-01-19 17:22:44', duration_point='261', completed='false', device='tablet')
# UsageEvent(user_id='user_606', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='114', completed='false', device='desktop')
# UsageEvent(user_id='user_946', music_id='track_44', timestamp='2025-01-19 17:22:44', duration_point='174', completed='true', device='desktop')
# UsageEvent(user_id='user_605', music_id='track_20', timestamp='2025-01-19 17:22:44', duration_point='32', completed='true', device='mobile')
# UsageEvent(user_id='user_906', music_id='track_83', timestamp='2025-01-19 17:22:44', duration_point='132', completed='false', device='desktop')
# UsageEvent(user_id='user_825', music_id='track_23', timestamp='2025-01-19 17:22:44', duration_point='70', completed='true', device='mobile')
# UsageEvent(user_id='user_31', music_id='track_25', timestamp='2025-01-19 17:22:44', duration_point='128', completed='false', device='desktop')
# UsageEvent(user_id='user_70', music_id='track_83', timestamp='2025-01-19 17:22:44', duration_point='42', completed='false', device='smart_tv')
# UsageEvent(user_id='user_276', music_id='track_93', timestamp='2025-01-19 17:22:44', duration_point='131', completed='true', device='desktop')
# UsageEvent(user_id='user_841', music_id='track_23', timestamp='2025-01-19 17:22:44', duration_point='156', completed='false', device='mobile')
# UsageEvent(user_id='user_831', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='165', completed='true', device='tablet')
# UsageEvent(user_id='user_912', music_id='track_18', timestamp='2025-01-19 17:22:44', duration_point='46', completed='true', device='smart_tv')
# UsageEvent(user_id='user_640', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='195', completed='true', device='smart_tv')
# UsageEvent(user_id='user_254', music_id='track_20', timestamp='2025-01-19 17:22:44', duration_point='265', completed='false', device='desktop')
# UsageEvent(user_id='user_243', music_id='track_44', timestamp='2025-01-19 17:22:44', duration_point='288', completed='true', device='tablet')
# UsageEvent(user_id='user_269', music_id='track_16', timestamp='2025-01-19 17:22:44', duration_point='200', completed='true', device='tablet')
# UsageEvent(user_id='user_658', music_id='track_98', timestamp='2025-01-19 17:22:44', duration_point='243', completed='false', device='desktop')
# UsageEvent(user_id='user_611', music_id='track_43', timestamp='2025-01-19 17:22:44', duration_point='173', completed='false', device='desktop')
# UsageEvent(user_id='user_896', music_id='track_78', timestamp='2025-01-19 17:22:44', duration_point='42', completed='false', device='desktop')
# UsageEvent(user_id='user_504', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='119', completed='true', device='smart_tv')
# UsageEvent(user_id='user_835', music_id='track_84', timestamp='2025-01-19 17:22:44', duration_point='195', completed='false', device='smart_tv')
# UsageEvent(user_id='user_5', music_id='track_17', timestamp='2025-01-19 17:22:44', duration_point='93', completed='true', device='mobile')
# UsageEvent(user_id='user_847', music_id='track_26', timestamp='2025-01-19 17:22:44', duration_point='170', completed='false', device='desktop')
# UsageEvent(user_id='user_988', music_id='track_96', timestamp='2025-01-19 17:22:44', duration_point='129', completed='true', device='tablet')
# UsageEvent(user_id='user_462', music_id='track_16', timestamp='2025-01-19 17:22:44', duration_point='246', completed='true', device='smart_tv')
# UsageEvent(user_id='user_162', music_id='track_41', timestamp='2025-01-19 17:22:44', duration_point='174', completed='false', device='smart_tv')
# UsageEvent(user_id='user_177', music_id='track_38', timestamp='2025-01-19 17:22:44', duration_point='273', completed='false', device='tablet')
# UsageEvent(user_id='user_996', music_id='track_44', timestamp='2025-01-19 17:22:44', duration_point='177', completed='false', device='desktop')
# UsageEvent(user_id='user_426', music_id='track_88', timestamp='2025-01-19 17:22:44', duration_point='197', completed='false', device='mobile')
# UsageEvent(user_id='user_454', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='122', completed='false', device='desktop')
# UsageEvent(user_id='user_74', music_id='track_23', timestamp='2025-01-19 17:22:44', duration_point='92', completed='true', device='smart_tv')
# UsageEvent(user_id='user_244', music_id='track_21', timestamp='2025-01-19 17:22:44', duration_point='174', completed='true', device='smart_tv')
# UsageEvent(user_id='user_248', music_id='track_57', timestamp='2025-01-19 17:22:44', duration_point='270', completed='false', device='desktop')
# UsageEvent(user_id='user_378', music_id='track_4', timestamp='2025-01-19 17:22:44', duration_point='101', completed='true', device='smart_tv')
# UsageEvent(user_id='user_594', music_id='track_86', timestamp='2025-01-19 17:22:44', duration_point='68', completed='true', device='mobile')
# UsageEvent(user_id='user_542', music_id='track_80', timestamp='2025-01-19 17:22:44', duration_point='99', completed='false', device='mobile')
# UsageEvent(user_id='user_51', music_id='track_50', timestamp='2025-01-19 17:22:44', duration_point='64', completed='false', device='desktop')
# UsageEvent(user_id='user_843', music_id='track_35', timestamp='2025-01-19 17:22:44', duration_point='112', completed='true', device='smart_tv')
# UsageEvent(user_id='user_888', music_id='track_64', timestamp='2025-01-19 17:22:44', duration_point='204', completed='false', device='mobile')
# UsageEvent(user_id='user_977', music_id='track_29', timestamp='2025-01-19 17:22:44', duration_point='207', completed='true', device='tablet')
# UsageEvent(user_id='user_634', music_id='track_85', timestamp='2025-01-19 17:22:44', duration_point='165', completed='false', device='tablet')
# UsageEvent(user_id='user_26', music_id='track_71', timestamp='2025-01-19 17:22:44', duration_point='153', completed='false', device='mobile')
# UsageEvent(user_id='user_72', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='273', completed='true', device='desktop')
# UsageEvent(user_id='user_390', music_id='track_11', timestamp='2025-01-19 17:22:44', duration_point='300', completed='false', device='mobile')
# UsageEvent(user_id='user_888', music_id='track_3', timestamp='2025-01-19 17:22:44', duration_point='62', completed='false', device='desktop')
# UsageEvent(user_id='user_595', music_id='track_35', timestamp='2025-01-19 17:22:44', duration_point='186', completed='true', device='mobile')
# UsageEvent(user_id='user_818', music_id='track_80', timestamp='2025-01-19 17:22:44', duration_point='206', completed='true', device='tablet')
# UsageEvent(user_id='user_255', music_id='track_47', timestamp='2025-01-19 17:22:44', duration_point='124', completed='true', device='smart_tv')
# UsageEvent(user_id='user_532', music_id='track_42', timestamp='2025-01-19 17:22:44', duration_point='258', completed='false', device='desktop')
# UsageEvent(user_id='user_869', music_id='track_14', timestamp='2025-01-19 17:22:44', duration_point='67', completed='false', device='smart_tv')
# UsageEvent(user_id='user_345', music_id='track_52', timestamp='2025-01-19 17:22:44', duration_point='246', completed='false', device='tablet')
# UsageEvent(user_id='user_339', music_id='track_3', timestamp='2025-01-19 17:22:44', duration_point='237', completed='true', device='mobile')
# UsageEvent(user_id='user_489', music_id='track_94', timestamp='2025-01-19 17:22:44', duration_point='218', completed='true', device='desktop')
# UsageEvent(user_id='user_104', music_id='track_33', timestamp='2025-01-19 17:22:44', duration_point='274', completed='false', device='smart_tv')
# UsageEvent(user_id='user_603', music_id='track_95', timestamp='2025-01-19 17:22:44', duration_point='204', completed='true', device='desktop')
# UsageEvent(user_id='user_830', music_id='track_87', timestamp='2025-01-19 17:22:44', duration_point='112', completed='false', device='tablet')
# UsageEvent(user_id='user_108', music_id='track_27', timestamp='2025-01-19 17:22:44', duration_point='143', completed='true', device='smart_tv')
# UsageEvent(user_id='user_116', music_id='track_81', timestamp='2025-01-19 17:22:44', duration_point='288', completed='true', device='tablet')
# UsageEvent(user_id='user_33', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='82', completed='true', device='desktop')
# UsageEvent(user_id='user_687', music_id='track_18', timestamp='2025-01-19 17:22:44', duration_point='68', completed='false', device='mobile')
# UsageEvent(user_id='user_952', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='198', completed='true', device='tablet')
# UsageEvent(user_id='user_658', music_id='track_96', timestamp='2025-01-19 17:22:44', duration_point='105', completed='true', device='desktop')
# UsageEvent(user_id='user_741', music_id='track_34', timestamp='2025-01-19 17:22:44', duration_point='78', completed='true', device='tablet')
# UsageEvent(user_id='user_249', music_id='track_46', timestamp='2025-01-19 17:22:44', duration_point='72', completed='false', device='desktop')
# UsageEvent(user_id='user_904', music_id='track_13', timestamp='2025-01-19 17:22:44', duration_point='39', completed='true', device='desktop')
# UsageEvent(user_id='user_764', music_id='track_49', timestamp='2025-01-19 17:22:44', duration_point='109', completed='true', device='mobile')
# UsageEvent(user_id='user_891', music_id='track_63', timestamp='2025-01-19 17:22:44', duration_point='250', completed='false', device='smart_tv')
# UsageEvent(user_id='user_480', music_id='track_40', timestamp='2025-01-19 17:22:44', duration_point='60', completed='false', device='desktop')
# UsageEvent(user_id='user_973', music_id='track_17', timestamp='2025-01-19 17:22:44', duration_point='247', completed='false', device='mobile')
# UsageEvent(user_id='user_765', music_id='track_15', timestamp='2025-01-19 17:22:44', duration_point='255', completed='true', device='desktop')
# UsageEvent(user_id='user_760', music_id='track_94', timestamp='2025-01-19 17:22:44', duration_point='118', completed='true', device='desktop')
# UsageEvent(user_id='user_349', music_id='track_67', timestamp='2025-01-19 17:22:44', duration_point='290', completed='false', device='tablet')
# UsageEvent(user_id='user_335', music_id='track_53', timestamp='2025-01-19 17:22:44', duration_point='273', completed='false', device='tablet')
# UsageEvent(user_id='user_113', music_id='track_26', timestamp='2025-01-19 17:22:44', duration_point='286', completed='false', device='smart_tv')
# UsageEvent(user_id='user_664', music_id='track_71', timestamp='2025-01-19 17:22:44', duration_point='289', completed='true', device='mobile')
# UsageEvent(user_id='user_906', music_id='track_44', timestamp='2025-01-19 17:22:44', duration_point='88', completed='false', device='smart_tv')
# UsageEvent(user_id='user_518', music_id='track_19', timestamp='2025-01-19 17:22:44', duration_point='148', completed='true', device='tablet')
# UsageEvent(user_id='user_687', music_id='track_73', timestamp='2025-01-19 17:22:44', duration_point='186', completed='true', device='smart_tv')
# UsageEvent(user_id='user_206', music_id='track_88', timestamp='2025-01-19 17:22:44', duration_point='243', completed='true', device='tablet')
# UsageEvent(user_id='user_532', music_id='track_0', timestamp='2025-01-19 17:22:44', duration_point='288', completed='false', device='smart_tv')
# UsageEvent(user_id='user_904', music_id='track_66', timestamp='2025-01-19 17:22:44', duration_point='155', completed='true', device='desktop')
# UsageEvent(user_id='user_563', music_id='track_37', timestamp='2025-01-19 17:22:44', duration_point='201', completed='true', device='mobile')
# UsageEvent(user_id='user_993', music_id='track_78', timestamp='2025-01-19 17:22:44', duration_point='263', completed='true', device='desktop')
# UsageEvent(user_id='user_442', music_id='track_71', timestamp='2025-01-19 17:22:44', duration_point='216', completed='false', device='tablet')
# UsageEvent(user_id='user_627', music_id='track_89', timestamp='2025-01-19 17:22:44', duration_point='103', completed='true', device='smart_tv')
# ...
# UsageEvent(user_id='user_82', music_id='track_58', timestamp='2025-01-19 17:24:14', duration_point='85', completed='true', device='smart_tv')
# UsageEvent(user_id='user_127', music_id='track_68', timestamp='2025-01-19 17:24:14', duration_point='242', completed='false', device='desktop')
# UsageEvent(user_id='user_675', music_id='track_76', timestamp='2025-01-19 17:24:14', duration_point='288', completed='false', device='smart_tv')
# UsageEvent(user_id='user_763', music_id='track_44', timestamp='2025-01-19 17:24:14', duration_point='73', completed='false', device='tablet')
# UsageEvent(user_id='user_861', music_id='track_63', timestamp='2025-01-19 17:24:14', duration_point='117', completed='true', device='desktop')
# UsageEvent(user_id='user_861', music_id='track_65', timestamp='2025-01-19 17:24:14', duration_point='82', completed='true', device='tablet')
# UsageEvent(user_id='user_469', music_id='track_97', timestamp='2025-01-19 17:24:14', duration_point='205', completed='false', device='desktop')
# UsageEvent(user_id='user_548', music_id='track_6', timestamp='2025-01-19 17:24:14', duration_point='100', completed='false', device='desktop')
# UsageEvent(user_id='user_616', music_id='track_53', timestamp='2025-01-19 17:24:14', duration_point='81', completed='false', device='desktop')
# UsageEvent(user_id='user_11', music_id='track_14', timestamp='2025-01-19 17:24:14', duration_point='104', completed='true', device='mobile')
# UsageEvent(user_id='user_346', music_id='track_22', timestamp='2025-01-19 17:24:14', duration_point='174', completed='true', device='desktop')
# UsageEvent(user_id='user_363', music_id='track_44', timestamp='2025-01-19 17:24:15', duration_point='108', completed='true', device='smart_tv')
# UsageEvent(user_id='user_93', music_id='track_57', timestamp='2025-01-19 17:24:15', duration_point='73', completed='false', device='tablet')
# UsageEvent(user_id='user_910', music_id='track_19', timestamp='2025-01-19 17:24:15', duration_point='259', completed='true', device='mobile')
# UsageEvent(user_id='user_106', music_id='track_12', timestamp='2025-01-19 17:24:15', duration_point='38', completed='true', device='mobile')
# UsageEvent(user_id='user_107', music_id='track_88', timestamp='2025-01-19 17:24:15', duration_point='246', completed='true', device='mobile')
# UsageEvent(user_id='user_163', music_id='track_23', timestamp='2025-01-19 17:24:15', duration_point='46', completed='false', device='desktop')
# UsageEvent(user_id='user_685', music_id='track_89', timestamp='2025-01-19 17:24:15', duration_point='70', completed='false', device='tablet')
# UsageEvent(user_id='user_440', music_id='track_79', timestamp='2025-01-19 17:24:15', duration_point='274', completed='false', device='desktop')
# UsageEvent(user_id='user_216', music_id='track_73', timestamp='2025-01-19 17:24:15', duration_point='155', completed='true', device='tablet')
# UsageEvent(user_id='user_290', music_id='track_92', timestamp='2025-01-19 17:24:15', duration_point='37', completed='false', device='desktop')
# UsageEvent(user_id='user_664', music_id='track_77', timestamp='2025-01-19 17:24:15', duration_point='296', completed='false', device='smart_tv')
# UsageEvent(user_id='user_477', music_id='track_40', timestamp='2025-01-19 17:24:15', duration_point='79', completed='true', device='mobile')
# UsageEvent(user_id='user_821', music_id='track_39', timestamp='2025-01-19 17:24:15', duration_point='140', completed='true', device='tablet')
# UsageEvent(user_id='user_881', music_id='track_88', timestamp='2025-01-19 17:24:15', duration_point='111', completed='false', device='desktop')
# UsageEvent(user_id='user_754', music_id='track_26', timestamp='2025-01-19 17:24:15', duration_point='265', completed='true', device='desktop')
# UsageEvent(user_id='user_472', music_id='track_8', timestamp='2025-01-19 17:24:15', duration_point='75', completed='false', device='tablet')
# UsageEvent(user_id='user_998', music_id='track_86', timestamp='2025-01-19 17:24:15', duration_point='255', completed='false', device='desktop')
# UsageEvent(user_id='user_131', music_id='track_62', timestamp='2025-01-19 17:24:15', duration_point='217', completed='true', device='desktop')
# UsageEvent(user_id='user_956', music_id='track_23', timestamp='2025-01-19 17:24:15', duration_point='41', completed='false', device='tablet')
# UsageEvent(user_id='user_35', music_id='track_48', timestamp='2025-01-19 17:24:15', duration_point='277', completed='true', device='mobile')
# UsageEvent(user_id='user_216', music_id='track_97', timestamp='2025-01-19 17:24:15', duration_point='199', completed='false', device='smart_tv')
# UsageEvent(user_id='user_924', music_id='track_94', timestamp='2025-01-19 17:24:15', duration_point='89', completed='true', device='tablet')
# UsageEvent(user_id='user_994', music_id='track_1', timestamp='2025-01-19 17:24:15', duration_point='97', completed='true', device='mobile')
# UsageEvent(user_id='user_272', music_id='track_83', timestamp='2025-01-19 17:24:15', duration_point='191', completed='true', device='desktop')
# UsageEvent(user_id='user_497', music_id='track_16', timestamp='2025-01-19 17:24:15', duration_point='291', completed='false', device='tablet')
# UsageEvent(user_id='user_107', music_id='track_73', timestamp='2025-01-19 17:24:15', duration_point='55', completed='true', device='smart_tv')
# UsageEvent(user_id='user_331', music_id='track_56', timestamp='2025-01-19 17:24:15', duration_point='220', completed='false', device='mobile')
# UsageEvent(user_id='user_187', music_id='track_74', timestamp='2025-01-19 17:24:15', duration_point='113', completed='false', device='smart_tv')
# UsageEvent(user_id='user_100', music_id='track_31', timestamp='2025-01-19 17:24:15', duration_point='273', completed='false', device='smart_tv')
# UsageEvent(user_id='user_388', music_id='track_92', timestamp='2025-01-19 17:24:15', duration_point='286', completed='false', device='tablet')
# UsageEvent(user_id='user_124', music_id='track_31', timestamp='2025-01-19 17:24:15', duration_point='248', completed='false', device='tablet')
# UsageEvent(user_id='user_842', music_id='track_95', timestamp='2025-01-19 17:24:15', duration_point='142', completed='true', device='mobile')
# UsageEvent(user_id='user_976', music_id='track_75', timestamp='2025-01-19 17:24:15', duration_point='222', completed='true', device='desktop')
# UsageEvent(user_id='user_0', music_id='track_62', timestamp='2025-01-19 17:24:15', duration_point='221', completed='true', device='tablet')
# UsageEvent(user_id='user_285', music_id='track_65', timestamp='2025-01-19 17:24:16', duration_point='297', completed='true', device='mobile')
# UsageEvent(user_id='user_294', music_id='track_0', timestamp='2025-01-19 17:24:16', duration_point='44', completed='false', device='tablet')
# UsageEvent(user_id='user_625', music_id='track_55', timestamp='2025-01-19 17:24:16', duration_point='125', completed='false', device='tablet')
# UsageEvent(user_id='user_331', music_id='track_51', timestamp='2025-01-19 17:24:16', duration_point='146', completed='true', device='smart_tv')
# UsageEvent(user_id='user_418', music_id='track_59', timestamp='2025-01-19 17:24:16', duration_point='37', completed='true', device='desktop')
# UsageEvent(user_id='user_857', music_id='track_69', timestamp='2025-01-19 17:24:16', duration_point='206', completed='true', device='mobile')
# UsageEvent(user_id='user_588', music_id='track_18', timestamp='2025-01-19 17:24:16', duration_point='255', completed='true', device='smart_tv')
# UsageEvent(user_id='user_307', music_id='track_32', timestamp='2025-01-19 17:24:16', duration_point='37', completed='false', device='mobile')
# UsageEvent(user_id='user_505', music_id='track_13', timestamp='2025-01-19 17:24:16', duration_point='41', completed='true', device='desktop')
# UsageEvent(user_id='user_768', music_id='track_59', timestamp='2025-01-19 17:24:16', duration_point='86', completed='false', device='mobile')
# UsageEvent(user_id='user_776', music_id='track_12', timestamp='2025-01-19 17:24:16', duration_point='179', completed='false', device='desktop')
# UsageEvent(user_id='user_924', music_id='track_67', timestamp='2025-01-19 17:24:16', duration_point='131', completed='false', device='mobile')
# UsageEvent(user_id='user_320', music_id='track_49', timestamp='2025-01-19 17:24:16', duration_point='95', completed='false', device='mobile')
# UsageEvent(user_id='user_667', music_id='track_49', timestamp='2025-01-19 17:24:16', duration_point='199', completed='true', device='tablet')
# UsageEvent(user_id='user_701', music_id='track_85', timestamp='2025-01-19 17:24:16', duration_point='94', completed='true', device='smart_tv')
# UsageEvent(user_id='user_953', music_id='track_94', timestamp='2025-01-19 17:24:16', duration_point='73', completed='true', device='tablet')
# UsageEvent(user_id='user_467', music_id='track_20', timestamp='2025-01-19 17:24:16', duration_point='299', completed='true', device='desktop')
# UsageEvent(user_id='user_806', music_id='track_12', timestamp='2025-01-19 17:24:16', duration_point='165', completed='true', device='mobile')
# UsageEvent(user_id='user_809', music_id='track_15', timestamp='2025-01-19 17:24:16', duration_point='254', completed='false', device='desktop')
# UsageEvent(user_id='user_956', music_id='track_24', timestamp='2025-01-19 17:24:16', duration_point='271', completed='false', device='mobile')
# UsageEvent(user_id='user_134', music_id='track_73', timestamp='2025-01-19 17:24:16', duration_point='36', completed='false', device='mobile')
# UsageEvent(user_id='user_866', music_id='track_66', timestamp='2025-01-19 17:24:16', duration_point='170', completed='true', device='mobile')
# UsageEvent(user_id='user_944', music_id='track_69', timestamp='2025-01-19 17:24:16', duration_point='113', completed='true', device='smart_tv')
# UsageEvent(user_id='user_625', music_id='track_56', timestamp='2025-01-19 17:24:16', duration_point='46', completed='false', device='desktop')
# UsageEvent(user_id='user_525', music_id='track_13', timestamp='2025-01-19 17:24:16', duration_point='84', completed='true', device='smart_tv')
# UsageEvent(user_id='user_844', music_id='track_53', timestamp='2025-01-19 17:24:16', duration_point='154', completed='false', device='smart_tv')
# UsageEvent(user_id='user_660', music_id='track_95', timestamp='2025-01-19 17:24:16', duration_point='235', completed='true', device='desktop')
# UsageEvent(user_id='user_424', music_id='track_64', timestamp='2025-01-19 17:24:16', duration_point='182', completed='false', device='mobile')
# UsageEvent(user_id='user_964', music_id='track_76', timestamp='2025-01-19 17:24:16', duration_point='168', completed='false', device='tablet')
# UsageEvent(user_id='user_639', music_id='track_53', timestamp='2025-01-19 17:24:16', duration_point='252', completed='true', device='tablet')
# UsageEvent(user_id='user_448', music_id='track_90', timestamp='2025-01-19 17:24:16', duration_point='88', completed='false', device='smart_tv')
# UsageEvent(user_id='user_46', music_id='track_37', timestamp='2025-01-19 17:24:16', duration_point='100', completed='false', device='mobile')
# UsageEvent(user_id='user_598', music_id='track_98', timestamp='2025-01-19 17:24:16', duration_point='131', completed='true', device='smart_tv')
# UsageEvent(user_id='user_180', music_id='track_93', timestamp='2025-01-19 17:24:16', duration_point='239', completed='false', device='desktop')
# UsageEvent(user_id='user_76', music_id='track_73', timestamp='2025-01-19 17:24:16', duration_point='138', completed='true', device='tablet')
# UsageEvent(user_id='user_355', music_id='track_74', timestamp='2025-01-19 17:24:16', duration_point='104', completed='false', device='smart_tv')
# UsageEvent(user_id='user_636', music_id='track_37', timestamp='2025-01-19 17:24:16', duration_point='284', completed='false', device='smart_tv')
# UsageEvent(user_id='user_260', music_id='track_72', timestamp='2025-01-19 17:24:16', duration_point='152', completed='false', device='tablet')
# UsageEvent(user_id='user_424', music_id='track_63', timestamp='2025-01-19 17:24:16', duration_point='205', completed='true', device='mobile')
# UsageEvent(user_id='user_847', music_id='track_51', timestamp='2025-01-19 17:24:16', duration_point='279', completed='false', device='smart_tv')
# UsageEvent(user_id='user_803', music_id='track_71', timestamp='2025-01-19 17:24:16', duration_point='201', completed='false', device='smart_tv')
# UsageEvent(user_id='user_249', music_id='track_8', timestamp='2025-01-19 17:24:16', duration_point='183', completed='true', device='mobile')
# UsageEvent(user_id='user_786', music_id='track_57', timestamp='2025-01-19 17:24:16', duration_point='179', completed='true', device='mobile')
# UsageEvent(user_id='user_106', music_id='track_0', timestamp='2025-01-19 17:24:16', duration_point='101', completed='false', device='desktop')
# UsageEvent(user_id='user_126', music_id='track_88', timestamp='2025-01-19 17:24:16', duration_point='155', completed='false', device='tablet')
# UsageEvent(user_id='user_390', music_id='track_10', timestamp='2025-01-19 17:24:16', duration_point='134', completed='false', device='mobile')
# UsageEvent(user_id='user_973', music_id='track_30', timestamp='2025-01-19 17:24:16', duration_point='133', completed='true', device='smart_tv')
# UsageEvent(user_id='user_511', music_id='track_18', timestamp='2025-01-19 17:24:16', duration_point='206', completed='false', device='mobile')
# UsageEvent(user_id='user_596', music_id='track_78', timestamp='2025-01-19 17:24:16', duration_point='243', completed='true', device='tablet')
# UsageEvent(user_id='user_588', music_id='track_51', timestamp='2025-01-19 17:24:16', duration_point='56', completed='true', device='mobile')
# UsageEvent(user_id='user_431', music_id='track_91', timestamp='2025-01-19 17:24:17', duration_point='170', completed='false', device='desktop')
# UsageEvent(user_id='user_9', music_id='track_78', timestamp='2025-01-19 17:24:17', duration_point='80', completed='true', device='tablet')
# UsageEvent(user_id='user_19', music_id='track_21', timestamp='2025-01-19 17:24:14', duration_point='201', completed='false', device='tablet')
# UsageEvent(user_id='user_782', music_id='track_67', timestamp='2025-01-19 17:24:14', duration_point='117', completed='false', device='smart_tv')
# UsageEvent(user_id='user_425', music_id='track_11', timestamp='2025-01-19 17:24:14', duration_point='107', completed='false', device='smart_tv')
# UsageEvent(user_id='user_898', music_id='track_76', timestamp='2025-01-19 17:24:14', duration_point='51', completed='true', device='desktop')
# UsageEvent(user_id='user_542', music_id='track_99', timestamp='2025-01-19 17:24:14', duration_point='145', completed='false', device='tablet')
# UsageEvent(user_id='user_689', music_id='track_8', timestamp='2025-01-19 17:24:14', duration_point='138', completed='false', device='smart_tv')
# UsageEvent(user_id='user_679', music_id='track_13', timestamp='2025-01-19 17:24:14', duration_point='239', completed='true', device='tablet')
# UsageEvent(user_id='user_137', music_id='track_3', timestamp='2025-01-19 17:24:14', duration_point='43', completed='true', device='desktop')
# UsageEvent(user_id='user_556', music_id='track_40', timestamp='2025-01-19 17:24:14', duration_point='241', completed='false', device='mobile')
# UsageEvent(user_id='user_462', music_id='track_41', timestamp='2025-01-19 17:24:14', duration_point='156', completed='false', device='smart_tv')
# UsageEvent(user_id='user_81', music_id='track_20', timestamp='2025-01-19 17:24:14', duration_point='97', completed='true', device='smart_tv')
# UsageEvent(user_id='user_482', music_id='track_15', timestamp='2025-01-19 17:24:14', duration_point='56', completed='false', device='smart_tv')
# UsageEvent(user_id='user_742', music_id='track_49', timestamp='2025-01-19 17:24:14', duration_point='276', completed='true', device='tablet')
# UsageEvent(user_id='user_819', music_id='track_77', timestamp='2025-01-19 17:24:14', duration_point='211', completed='true', device='desktop')
# UsageEvent(user_id='user_192', music_id='track_72', timestamp='2025-01-19 17:24:15', duration_point='280', completed='true', device='smart_tv')

# %%
for track_id, plays in analizer.get_trending_tracks():
    print(f"\nТрек {track_id}")

        # Детальна статистика
    stats = analizer.get_track_stats(track_id)
    print(f"Загальні прослуховування: {stats['total_plays']}")
    print(f"Унікальні слухачі: {stats['unique_listeners']}")
    print(f"Середня тривалість прослуховування: {stats['avg_duration']:.2f}")
    print(f"Відсоток завершених прослуховувань: {stats['completion_rate']:.1%}")
    
    # Розподіл за пристроями
    print("\nРозподіл за пристроями:")
    for device, percentage in stats['device_distribution'].items():
        print(f"  - {device}: {percentage:.1%}")
    
    # Рекомендації
    print("\nРекомендовані треки:")
    for rec_id, score in analizer.get_track_recommendations(track_id):
        print(f"  - {rec_id} (score: {score:.2f})")
# Out:
# Трек track_84
# Загальні прослуховування: 132
# Унікальні слухачі: 53
# Середня тривалість прослуховування: 174.12
# Відсоток завершених прослуховувань: 53.0%
#
# Розподіл за пристроями:
#   - smart_tv: 26.5%
#   - tablet: 24.2%
#   - desktop: 24.2%
#   - mobile: 25.0%
#
# Рекомендовані треки:
#   - track_44 (score: 0.03)
#   - track_32 (score: 0.03)
#   - track_99 (score: 0.03)
#   - track_53 (score: 0.03)
#   - track_30 (score: 0.03)
#
# Трек track_94
# Загальні прослуховування: 124
# Унікальні слухачі: 62
# Середня тривалість прослуховування: 161.62
# Відсоток завершених прослуховувань: 46.0%
#
# Розподіл за пристроями:
#   - tablet: 30.6%
#   - smart_tv: 22.6%
#   - desktop: 25.0%
#   - mobile: 21.8%
#
# Рекомендовані треки:
#   - track_84 (score: 0.05)
#   - track_60 (score: 0.04)
#   - track_46 (score: 0.04)
#   - track_61 (score: 0.03)
#   - track_14 (score: 0.03)
#
# Трек track_70
# Загальні прослуховування: 120
# Унікальні слухачі: 56
# Середня тривалість прослуховування: 160.16
# Відсоток завершених прослуховувань: 49.2%
#
# Розподіл за пристроями:
#   - tablet: 32.5%
#   - desktop: 18.3%
#   - mobile: 23.3%
#   - smart_tv: 25.8%
#
# Рекомендовані треки:
#   - track_35 (score: 0.05)
#   - track_98 (score: 0.04)
#   - track_68 (score: 0.04)
#   - track_66 (score: 0.03)
#   - track_23 (score: 0.03)
#
# Трек track_52
# Загальні прослуховування: 119
# Унікальні слухачі: 65
# Середня тривалість прослуховування: 172.51
# Відсоток завершених прослуховувань: 50.4%
#
# Розподіл за пристроями:
#   - smart_tv: 25.2%
#   - mobile: 29.4%
#   - desktop: 31.1%
#   - tablet: 14.3%
#
# Рекомендовані треки:
#   - track_37 (score: 0.04)
#   - track_36 (score: 0.04)
#   - track_89 (score: 0.04)
#   - track_21 (score: 0.04)
#   - track_59 (score: 0.03)
#
# Трек track_44
# Загальні прослуховування: 118
# Унікальні слухачі: 59
# Середня тривалість прослуховування: 166.92
# Відсоток завершених прослуховувань: 55.1%
#
# Розподіл за пристроями:
#   - desktop: 33.1%
#   - tablet: 22.9%
#   - smart_tv: 24.6%
#   - mobile: 19.5%
#
# Рекомендовані треки:
#   - track_48 (score: 0.04)
#   - track_17 (score: 0.04)
#   - track_49 (score: 0.03)
#   - track_61 (score: 0.03)
#   - track_56 (score: 0.03)
#
# Трек track_88
# Загальні прослуховування: 115
# Унікальні слухачі: 61
# Середня тривалість прослуховування: 162.36
# Відсоток завершених прослуховувань: 46.1%
#
# Розподіл за пристроями:
#   - desktop: 33.9%
#   - mobile: 27.8%
#   - tablet: 24.3%
#   - smart_tv: 13.9%
#
# Рекомендовані треки:
#   - track_43 (score: 0.04)
#   - track_52 (score: 0.04)
#   - track_42 (score: 0.03)
#   - track_66 (score: 0.03)
#   - track_62 (score: 0.03)
#
# Трек track_57
# Загальні прослуховування: 115
# Унікальні слухачі: 51
# Середня тривалість прослуховування: 156.68
# Відсоток завершених прослуховувань: 43.5%
#
# Розподіл за пристроями:
#   - mobile: 29.6%
#   - tablet: 13.0%
#   - desktop: 25.2%
#   - smart_tv: 32.2%
#
# Рекомендовані треки:
#   - track_50 (score: 0.03)
#   - track_53 (score: 0.03)
#   - track_36 (score: 0.03)
#   - track_34 (score: 0.03)
#   - track_20 (score: 0.03)
#
# Трек track_38
# Загальні прослуховування: 115
# Унікальні слухачі: 55
# Середня тривалість прослуховування: 166.97
# Відсоток завершених прослуховувань: 60.0%
#
# Розподіл за пристроями:
#   - smart_tv: 21.7%
#   - desktop: 27.8%
#   - tablet: 21.7%
#   - mobile: 28.7%
#
# Рекомендовані треки:
#   - track_99 (score: 0.05)
#   - track_38 (score: 0.05)
#   - track_98 (score: 0.04)
#   - track_2 (score: 0.04)
#   - track_9 (score: 0.03)
#
# Трек track_68
# Загальні прослуховування: 114
# Унікальні слухачі: 52
# Середня тривалість прослуховування: 173.31
# Відсоток завершених прослуховувань: 39.5%
#
# Розподіл за пристроями:
#   - desktop: 28.1%
#   - tablet: 25.4%
#   - mobile: 21.9%
#   - smart_tv: 24.6%
#
# Рекомендовані треки:
#   - track_5 (score: 0.05)
#   - track_59 (score: 0.04)
#   - track_73 (score: 0.04)
#   - track_78 (score: 0.03)
#   - track_20 (score: 0.03)
#
# Трек track_34
# Загальні прослуховування: 113
# Унікальні слухачі: 54
# Середня тривалість прослуховування: 171.13
# Відсоток завершених прослуховувань: 48.7%
#
# Розподіл за пристроями:
#   - smart_tv: 23.9%
#   - tablet: 25.7%
#   - desktop: 27.4%
#   - mobile: 23.0%
#
# Рекомендовані треки:
#   - track_95 (score: 0.05)
#   - track_84 (score: 0.05)
#   - track_18 (score: 0.04)
#   - track_42 (score: 0.03)
#   - track_44 (score: 0.03)
